# %% [markdown]
# # Student Questionnaire

# %%
import pandas as pd
from os.path import join as joinpath

# %%
path = r'D:\BigQueryDatabase\PISA\2018'
filename = 'cy07_msu_stu_cog'
path = joinpath(path,  filename+'.csv')
pd.read_csv(path, nrows = 100)
# Out:
#     CNTRYID  CNT  CNTSCHID  CNTSTUID   CYC  NatCen  Region  STRATUM  SUBNATIO  \
# 0       8.0  ALB  800115.0  800001.0  07MS     800   800.0  ALB0107     80000
# 1       8.0  ALB  800300.0  800002.0  07MS     800   800.0  ALB0105     80000
# 2       8.0  ALB  800088.0  800003.0  07MS     800   800.0  ALB0101     80000
# 3       8.0  ALB  800014.0  800004.0  07MS     800   800.0  ALB0109     80000
# 4       8.0  ALB  800294.0  800005.0  07MS     800   800.0  ALB0203     80000
# ..      ...  ...       ...       ...   ...     ...     ...      ...       ...
# 95      8.0  ALB  800191.0  800106.0  07MS     800   800.0  ALB0101     80000
# 96      8.0  ALB  800196.0  800107.0  07MS     800   800.0  ALB0105     80000
# 97      8.0  ALB  800009.0  800108.0  07MS     800   800.0  ALB0203     80000
# 98      8.0  ALB  800116.0  800109.0  07MS     800   800.0  ALB0203     80000
# 99      8.0  ALB  800211.0  800110.0  07MS     800   800.0  ALB0101     80000
#
# ...
