# %% [markdown]
# # Extract Transform and Load (ETL) Process for the Programme for International Students Assessment (PISA) data

# %% [markdown]
# ## Introduction
# Here I document the series of steps followed to take the data from PISA and structure it properly for later analysis.
# ## Data Extraction
# The data was extracted from the [official PISA data website](https://www.oecd.org/pisa/data/). I first downloaded and processed the data for the year [2018](https://www.oecd.org/pisa/data/2018database/). After defining the necessary functions and processes, I will apply them for the [2015](https://www.oecd.org/pisa/data/2015database/) data. Ideally, the process is sufficiently robust it can be extended to the other years where data is available (i.e. 2000, 2003, 2006, 2009 and 2012).
#
# The data files provided are the following: Student Questionnaire, School Questionnaire, Teacher Questionnaire, Cognitive item data, and Questionnaire Timing. These three most important ones are the ones containing responses by the students, school and teacher.
#
#
# * Student Questionnaire:
# * School Questionnaire:
# * Teacher Questionnaire:
# * Cognitive item data:
# * Questionnaire Timing:
# *
#
#
# ## Data Processing
# ### Codebooks
#
#
# Most of the data in this dataset is codified. This file contains the way to de-codify the different variables. It was not very well formatted, so I had to fix it before proceeding.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The codebook data can be seen below. First of all, we only need the following columns:
#
# * NAME: the column containing the variable name that shows up in the data file.
# * VARLABEL: the label of the variable contained in the NAME column. We want to keep this especially for those variables with names that aren't so intuitive.
# * VAL: These are the codes showing up in the data files under the variable name showing up in the columnd NAME.
# * LABEL: these are the labels of the codes in the VAL column.

# %%
codebook_df = pd.read_excel(r"D:\Data Science Folder\PISA Analysis\Data\2018\PISA2018_CODEBOOK.xlsx")
codebook_df.head(10)
# Out:
#       NAME            VARLABEL TYPE FORMAT  VARNUM MINMAX  VAL  \
# 0  CNTRYID  Country Identifier  NUM    3.0     1.0  8-840  NaN
# 1      NaN                 NaN  NaN    NaN     NaN    NaN    8
# 2      NaN                 NaN  NaN    NaN     NaN    NaN   31
# 3      NaN                 NaN  NaN    NaN     NaN    NaN   32
# 4      NaN                 NaN  NaN    NaN     NaN    NaN   36
# 5      NaN                 NaN  NaN    NaN     NaN    NaN   40
# 6      NaN                 NaN  NaN    NaN     NaN    NaN   56
# 7      NaN                 NaN  NaN    NaN     NaN    NaN   70
# 8      NaN                 NaN  NaN    NaN     NaN    NaN   76
# 9      NaN                 NaN  NaN    NaN     NaN    NaN   96
#
#                     LABEL   COUNT   PERCENT
# 0                     NaN     NaN       NaN
# 1                 Albania  3375.0  3.143424
# 2       Baku (Azerbaijan)  4077.0  3.797256
# 3               Argentina     0.0  0.000000
# 4               Australia     0.0  0.000000
# 5                 Austria     0.0  0.000000
# 6                 Belgium     0.0  0.000000
# 7  Bosnia and Herzegovina     0.0  0.000000
# 8                  Brazil  8969.0  8.353591
# 9       Brunei Darussalam     0.0  0.000000

# %% [markdown]
# In a properly structured database, the data as seen below would need to be separated into several tables. For example, a table containing only the data for NAME = "CNTRYID" such that one could join by VAL and get the country labels.
#
# Instead of having several tables, an alternative could be to keep this table as is and simply filtering before joining. This is how it will be done. In order to do so, all of the rows in the column LABEL need to be identified by the corresponding NAME (and VARLABEL). Right now, these are all showing "NaN" instead.

# %%
df = codebook_df[["NAME", "VARLABEL","VAL", "LABEL"]]
df.head(10)
# Out:
#       NAME            VARLABEL  VAL                   LABEL
# 0  CNTRYID  Country Identifier  NaN                     NaN
# 1      NaN                 NaN    8                 Albania
# 2      NaN                 NaN   31       Baku (Azerbaijan)
# 3      NaN                 NaN   32               Argentina
# 4      NaN                 NaN   36               Australia
# 5      NaN                 NaN   40                 Austria
# 6      NaN                 NaN   56                 Belgium
# 7      NaN                 NaN   70  Bosnia and Herzegovina
# 8      NaN                 NaN   76                  Brazil
# 9      NaN                 NaN   96       Brunei Darussalam

# %% [markdown]
# To fix this, I remove the missing values to get a table that contains unique NAME and VARLABEL columns. Then, by resetting the index, I obtain a list column that essentially counts how many rows went by before changing value for the column NAME. I shift this variable back so i can substract it and get how many times each value in NAME needs to be repeated. The only missing value results on the very last row, because shifting has run out of rows. For this case, I simply use the number of rows in the original dataframe to substract.

# %%
df2 = df[["NAME", "VARLABEL"]].dropna().reset_index()
df2["repeat"] = df2[["index"]].shift(-1) - df2[["index"]]
df2[["repeat"]] = df2[["repeat"]].fillna(len(df) - max(df2["index"]))
df2.head()
# Out:
#    index       NAME                     VARLABEL  repeat
# 0      0    CNTRYID           Country Identifier    84.0
# 1     84        CNT     Country code 3-character    83.0
# 2    167   CNTSCHID              Intl. School ID     2.0
# 3    169   CNTTCHID             Intl. Teacher ID     2.0
# 4    171  TEACHERID  Teacher identification code     4.0

# %% [markdown]
# With this, I can now repeat the rows ...

# %%
df3 = pd.DataFrame(df2["NAME"].repeat(df2["repeat"].tolist())).reset_index()[["NAME"]]
df3["VARLABEL"] = pd.DataFrame(df2["VARLABEL"].repeat(df2["repeat"].tolist())).reset_index()[["VARLABEL"]]
df3.head()
# Out:
#       NAME            VARLABEL
# 0  CNTRYID  Country Identifier
# 1  CNTRYID  Country Identifier
# 2  CNTRYID  Country Identifier
# 3  CNTRYID  Country Identifier
# 4  CNTRYID  Country Identifier

# %% [markdown]
# ... and past them to the original dataframe.

# %%
codebook_df[["NAME","VARLABEL"]] = df3[["NAME","VARLABEL"]]
codebook_df = codebook_df[["NAME", "VARLABEL","VAL", "LABEL"]]
codebook_df
# Out:
#                   NAME                                           VARLABEL  \
# 0              CNTRYID                                 Country Identifier
# 1              CNTRYID                                 Country Identifier
# 2              CNTRYID                                 Country Identifier
# 3              CNTRYID                                 Country Identifier
# 4              CNTRYID                                 Country Identifier
# 5              CNTRYID                                 Country Identifier
# 6              CNTRYID                                 Country Identifier
# 7              CNTRYID                                 Country Identifier
# 8              CNTRYID                                 Country Identifier
# 9              CNTRYID                                 Country Identifier
# 10             CNTRYID                                 Country Identifier
# 11             CNTRYID                                 Country Identifier
# 12             CNTRYID                                 Country Identifier
# 13             CNTRYID                                 Country Identifier
# 14             CNTRYID                                 Country Identifier
# 15             CNTRYID                                 Country Identifier
# 16             CNTRYID                                 Country Identifier
# 17             CNTRYID                                 Country Identifier
# 18             CNTRYID                                 Country Identifier
# 19             CNTRYID                                 Country Identifier
# 20             CNTRYID                                 Country Identifier
# 21             CNTRYID                                 Country Identifier
# 22             CNTRYID                                 Country Identifier
# 23             CNTRYID                                 Country Identifier
# 24             CNTRYID                                 Country Identifier
# 25             CNTRYID                                 Country Identifier
# 26             CNTRYID                                 Country Identifier
# 27             CNTRYID                                 Country Identifier
# 28             CNTRYID                                 Country Identifier
# 29             CNTRYID                                 Country Identifier
# ...                ...                                                ...
# 4822        FEEDBINSTR            Feedback provided by the teachers (WLE)
# 4823          TCATTIMM       Teacher's attitudes towards immigrants (WLE)
# 4824          TCATTIMM       Teacher's attitudes towards immigrants (WLE)
# 4825          TCATTIMM       Teacher's attitudes towards immigrants (WLE)
# 4826          TCATTIMM       Teacher's attitudes towards immigrants (WLE)
# 4827          TCATTIMM       Teacher's attitudes towards immigrants (WLE)
# 4828          TCATTIMM       Teacher's attitudes towards immigrants (WLE)
# 4829           GCTRAIN      Teacher's training on global competence (WLE)
# 4830           GCTRAIN      Teacher's training on global competence (WLE)
# 4831           GCTRAIN      Teacher's training on global competence (WLE)
# 4832           GCTRAIN      Teacher's training on global competence (WLE)
# 4833           GCTRAIN      Teacher's training on global competence (WLE)
# 4834           GCTRAIN      Teacher's training on global competence (WLE)
# 4835            TCMCEG  Teachers' multicultural and egalitarian belief...
# 4836            TCMCEG  Teachers' multicultural and egalitarian belief...
# 4837            TCMCEG  Teachers' multicultural and egalitarian belief...
# 4838            TCMCEG  Teachers' multicultural and egalitarian belief...
# 4839            TCMCEG  Teachers' multicultural and egalitarian belief...
# 4840            TCMCEG  Teachers' multicultural and egalitarian belief...
# 4841            GCSELF  Teacher's self-efficacy in multicultural envir...
# 4842            GCSELF  Teacher's self-efficacy in multicultural envir...
# 4843            GCSELF  Teacher's self-efficacy in multicultural envir...
# 4844            GCSELF  Teacher's self-efficacy in multicultural envir...
# 4845            GCSELF  Teacher's self-efficacy in multicultural envir...
# 4846            GCSELF  Teacher's self-efficacy in multicultural envir...
# 4847     W_SCHGRNRABWT      GRADE NONRESPONSE ADJUSTED SCHOOL BASE WEIGHT
# 4848     W_SCHGRNRABWT      GRADE NONRESPONSE ADJUSTED SCHOOL BASE WEIGHT
# 4849  W_FSTUWT_SCH_SUM                                    Sum of W_FSTUWT
# 4850  W_FSTUWT_SCH_SUM                                    Sum of W_FSTUWT
# 4851           VER_DAT                      Date of the database creation
#
#                  VAL                   LABEL
# 0                NaN                     NaN
# 1                  8                 Albania
# 2                 31       Baku (Azerbaijan)
# 3                 32               Argentina
# 4                 36               Australia
# 5                 40                 Austria
# 6                 56                 Belgium
# 7                 70  Bosnia and Herzegovina
# 8                 76                  Brazil
# 9                 96       Brunei Darussalam
# 10               100                Bulgaria
# 11               112                 Belarus
# 12               124                  Canada
# 13               152                   Chile
# 14               158          Chinese Taipei
# 15               170                Colombia
# 16               188              Costa Rica
# 17               191                 Croatia
# 18               196                  Cyprus
# 19               203          Czech Republic
# 20               208                 Denmark
# 21               214      Dominican Republic
# 22               233                 Estonia
# 23               246                 Finland
# 24               250                  France
# 25               268                 Georgia
# 26               276                 Germany
# 27               300                  Greece
# 28               344               Hong Kong
# 29               348                 Hungary
# ...              ...                     ...
# 4822  SYSTEM MISSING                 Missing
# 4823             NaN                     NaN
# 4824      .V/9999995              Valid Skip
# 4825      .N/9999997          Not Applicable
# 4826      .I/9999998                 Invalid
# 4827      .M/9999999             No Response
# 4828  SYSTEM MISSING                 Missing
# 4829             NaN                     NaN
# 4830      .V/9999995              Valid Skip
# 4831      .N/9999997          Not Applicable
# 4832      .I/9999998                 Invalid
# 4833      .M/9999999             No Response
# 4834  SYSTEM MISSING                 Missing
# 4835             NaN                     NaN
# 4836      .V/9999995              Valid Skip
# 4837      .N/9999997          Not Applicable
# 4838      .I/9999998                 Invalid
# 4839      .M/9999999             No Response
# 4840  SYSTEM MISSING                 Missing
# 4841             NaN                     NaN
# 4842      .V/9999995              Valid Skip
# 4843      .N/9999997          Not Applicable
# 4844      .I/9999998                 Invalid
# 4845      .M/9999999             No Response
# 4846  SYSTEM MISSING                 Missing
# 4847             NaN                     NaN
# 4848  SYSTEM MISSING                 Missing
# 4849             NaN                     NaN
# 4850  SYSTEM MISSING                 Missing
# 4851             NaN                     NaN
#
# [4852 rows x 4 columns]

# %%
codebook_df.to_csv(r"D:\Data Science Folder\PISA Analysis\Data\2018\codebook_df.csv")

# %% [markdown]
# ### School Questionnaire
# This data contains variable names with a code that is related to the question asked. However, no codebook was officially provided. In this case, I decided to take a summary file provided by PISA to create a codebook.

# %%
df = pd.read_excel(r"D:\Data Science Folder\PISA Analysis\Data\2018\2018_Compendia_Questionnaire\bkg\pisa_ms_bkg_overall_sch_compendium.xlsx", 
                  sheet_name = "Table of Contents").reset_index().rename(columns = {"index":"varname", "Table of Contents": "varlabels"})
df.head()
# Out:
#       varname                                          varlabels
# 0  SC001Q01TA  Which of the following definitions best descri...
# 1  SC013Q01TA       Is your school a public or a private school?
# 2  SC017Q01NA  School's instruction hindered by: A lack of te...
# 3  SC017Q02NA  School's instruction hindered by: Inadequate o...
# 4  SC017Q03NA  School's instruction hindered by: A lack of as...

# %%
df3 = pd.DataFrame(columns = ["value", "labels", "varname"])
for i in range(0,len(df)-1):
    df2 = pd.read_excel(r"D:\Data Science Folder\PISA Analysis\Data\2018\2018_Compendia_Questionnaire\bkg\pisa_ms_bkg_overall_sch_compendium.xlsx", 
                  sheet_name = df["varname"].iloc[i], 
              skiprows=0, 
              nrows=1)
    df2 = pd.DataFrame(df2.iloc[0][4:].dropna().reset_index().iloc[:,1]).reset_index()
    df2["index"] = df2["index"]+1
    df2 = df2.rename(columns = {0:"labels", "index":"value"})
    df2["varname"] =  df["varname"].iloc[i]
    df3 = df3.append(df2)
df3 = df3.reset_index().drop(['index'],axis = 1)
df3.head()
# Out:
#     value                                             labels     varname
# 0       1  A village, hamlet or rural area (fewer than 3 ...  SC001Q01TA
# 1       2        A small town (3 000 to about 15 000 people)  SC001Q01TA
# 2       3            A town (15 000 to about 100 000 people)  SC001Q01TA
# 3       4         A city (100 000 to about 1 000 000 people)  SC001Q01TA
# 4       5          A large city (with over 1 000 000 people)  SC001Q01TA
# 5       6                                         Valid Skip  SC001Q01TA
# 6       7                                     Not Applicable  SC001Q01TA
# 7       8                                            Invalid  SC001Q01TA
# 8       9                                        No Response  SC001Q01TA
# 9       1  A public school (Managed by a public education...  SC013Q01TA
# 10      2  A private school (Managed by a non-government ...  SC013Q01TA
# 11      3                                         Valid Skip  SC013Q01TA
# 12      4                                     Not Applicable  SC013Q01TA
# 13      5                                            Invalid  SC013Q01TA
# 14      6                                        No Response  SC013Q01TA
# 15      1                                         Not at all  SC017Q01NA
# 16      2                                        Very little  SC017Q01NA
# 17      3                                     To some extent  SC017Q01NA
# 18      4                                              A lot  SC017Q01NA
# 19      5                                         Valid Skip  SC017Q01NA
# 20      6                                     Not Applicable  SC017Q01NA
# 21      7                                            Invalid  SC017Q01NA
# 22      8                                        No Response  SC017Q01NA
# 23      1                                         Not at all  SC017Q02NA
# 24      2                                        Very little  SC017Q02NA
# 25      3                                     To some extent  SC017Q02NA
# 26      4                                              A lot  SC017Q02NA
# 27      5                                         Valid Skip  SC017Q02NA
# 28      6                                     Not Applicable  SC017Q02NA
# 29      7                                            Invalid  SC017Q02NA
# ..    ...                                                ...         ...
# 680     3                                         Valid Skip  SC152Q01HA
# 681     4                                     Not Applicable  SC152Q01HA
# 682     5                                            Invalid  SC152Q01HA
# 683     6                                        No Response  SC152Q01HA
# 684     1                                   Enrichment  only  SC160Q01WA
# 685     2                                     Remedial  only  SC160Q01WA
# 686     3                    Both  enrichment  and  remedial  SC160Q01WA
# 687     4  Without differentiation depending on the prior...  SC160Q01WA
# 688     5                                         Valid Skip  SC160Q01WA
# 689     6                                     Not Applicable  SC160Q01WA
# 690     7                                            Invalid  SC160Q01WA
# 691     8                                        No Response  SC160Q01WA
# 692     1                                                Yes  SC052Q01NA
# 693     2                                                 No  SC052Q01NA
# 694     3                                         Valid Skip  SC052Q01NA
# 695     4                                     Not Applicable  SC052Q01NA
# 696     5                                            Invalid  SC052Q01NA
# 697     6                                        No Response  SC052Q01NA
# 698     1                                                Yes  SC052Q02NA
# 699     2                                                 No  SC052Q02NA
# 700     3                                         Valid Skip  SC052Q02NA
# 701     4                                     Not Applicable  SC052Q02NA
# 702     5                                            Invalid  SC052Q02NA
# 703     6                                        No Response  SC052Q02NA
# 704     1                                                Yes  SC052Q03HA
# 705     2                                                 No  SC052Q03HA
# 706     3                                         Valid Skip  SC052Q03HA
# 707     4                                     Not Applicable  SC052Q03HA
# 708     5                                            Invalid  SC052Q03HA
# 709     6                                        No Response  SC052Q03HA
#
# [710 rows x 3 columns]

# %%
SchoolQuestionnaireCodebook = pd.merge(df,df3,on = "varname")

# %%
SQ_2018 = pd.read_sas(r"D:\Data Science Folder\PISA Analysis\Data\2018\2018_School_Questionnaire_Data_Files\cy07_msu_sch_qqq.sas7bdat", encoding = "iso-8859-1")

# %%
SQ_2018.columns.to_series().to_string
# Out:
# <bound method Series.to_string of CNTRYID                      CNTRYID
# CNT                              CNT
# CNTSCHID                    CNTSCHID
# CYC                              CYC
# NatCen                        NatCen
# Region                        Region
# STRATUM                      STRATUM
# SUBNATIO                    SUBNATIO
# OECD                            OECD
# ADMINMODE                  ADMINMODE
# LANGTEST                    LANGTEST
# SC001Q01TA                SC001Q01TA
# SC013Q01TA                SC013Q01TA
# SC016Q01TA                SC016Q01TA
# SC016Q02TA                SC016Q02TA
# SC016Q03TA                SC016Q03TA
# SC016Q04TA                SC016Q04TA
# SC017Q01NA                SC017Q01NA
# SC017Q02NA                SC017Q02NA
# SC017Q03NA                SC017Q03NA
# SC017Q04NA                SC017Q04NA
# SC017Q05NA                SC017Q05NA
# SC017Q06NA                SC017Q06NA
# SC017Q07NA                SC017Q07NA
# SC017Q08NA                SC017Q08NA
# SC161Q01SA                SC161Q01SA
# SC161Q02SA                SC161Q02SA
# SC161Q03SA                SC161Q03SA
# SC161Q04SA                SC161Q04SA
# SC161Q05SA                SC161Q05SA
#                           ...
# SC064Q04NA                SC064Q04NA
# SC152Q01HA                SC152Q01HA
# SC160Q01WA                SC160Q01WA
# SC052Q01NA                SC052Q01NA
# SC052Q02NA                SC052Q02NA
# SC052Q03HA                SC052Q03HA
# PRIVATESCH                PRIVATESCH
# SCHLTYPE                    SCHLTYPE
# STRATIO                      STRATIO
# SCHSIZE                      SCHSIZE
# RATCMP1                      RATCMP1
# RATCMP2                      RATCMP2
# TOTAT                          TOTAT
# PROATCE                      PROATCE
# PROAT5AB                    PROAT5AB
# PROAT5AM                    PROAT5AM
# PROAT6                        PROAT6
# CLSIZE                        CLSIZE
# CREACTIV                    CREACTIV
# EDUSHORT                    EDUSHORT
# STAFFSHORT                STAFFSHORT
# STUBEHA                      STUBEHA
# TEACHBEHA                  TEACHBEHA
# SCMCEG                        SCMCEG
# W_SCHGRNRABWT          W_SCHGRNRABWT
# W_FSTUWT_SCH_SUM    W_FSTUWT_SCH_SUM
# SENWT                          SENWT
# VER_DAT                      VER_DAT
# i                                  i
# M                                  M
# Length: 198, dtype: object>

# %%
SQ_2018["SC013Q01TA"]
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        2.0
# 7        1.0
# 8        2.0
# 9        2.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       2.0
# 16       1.0
# 17       1.0
# 18       2.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       2.0
# 23       1.0
# 24       1.0
# 25       1.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       1.0
#         ...
# 21873    1.0
# 21874    1.0
# 21875    1.0
# 21876    1.0
# 21877    1.0
# 21878    1.0
# 21879    1.0
# 21880    1.0
# 21881    1.0
# 21882    1.0
# 21883    1.0
# 21884    1.0
# 21885    1.0
# 21886    1.0
# 21887    1.0
# 21888    1.0
# 21889    1.0
# 21890    1.0
# 21891    1.0
# 21892    1.0
# 21893    1.0
# 21894    1.0
# 21895    1.0
# 21896    1.0
# 21897    1.0
# 21898    1.0
# 21899    1.0
# 21900    1.0
# 21901    1.0
# 21902    1.0
# Name: SC013Q01TA, Length: 21903, dtype: float64
